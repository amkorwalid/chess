# %% [markdown]
# <a href="https://colab.research.google.com/github/amkorwalid/chess/blob/main/notebooks/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Initialization...")
# Out:
# Initialization...
